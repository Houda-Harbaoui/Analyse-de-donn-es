# %% [markdown]
# # Polytech Sorbonne-                                                                                    2021/2020

# %% [markdown]
# # 1. Exercices de révision

# %% [markdown]
# # Exercice 1:
# L’utilisateur donne un entier supérieur à 1 et le programme affiche, s’il y en a, tous ses diviseurs propres sans répétition ainsi que leur nombre. S’il n’y en a pas, il indique qu’il est premier. Par exemple :
# Entrez un entier strictement positif : 12
# Diviseurs propres sans répétition de 12 : 2 3 4 6 (soit 4 diviseurs propres)
# Entrez un entier strictement positif : 13 Diviseurs propres sans répétition de 13 : aucun ! Il est premier

# %%
# Correction
"""Diviseurs propres d'un entier."""

# Programme principal =========================================================
n = int(input("Entrez un entier strictement positif :"))
while n < 1:
    n = int(input("Entrez un entier STRICTEMENT POSITIF, s.v.p. :"))

i = 2 # plus petit diviseur possible de n
cpt = 0 # initialise le compteur de divisions
p = n/2 # calculé une fois dans la boucle

print("Diviseurs propres sans répétition de", n, " :", end=' ')
while i <= p :
    if n%i == 0:
        cpt += 1
        print(i, end=' ')
    i += 1

if not cpt :
    print("aucun ! Il est premier.")
else :
    print("(soit", cpt, "diviseurs propres)")

# %% [markdown]
# # Exercice 2
# Écrire une fonction eval(op, x1, x2) qui prend un caractère représentant une des 4 opérations binaires et 2 valeurs entières et qui applique l'opération à ces valeurs et en retourne le résultat.

# %%
# Correction
def eval(op, x1, x2):
    if op == '+':
        return x1 + x2
    elif op == '-':
        return x1 - x2
    elif op == '*':
        return x1 * x2
    else:
        return x1 // x2

eval('+',4,5)
# Out:
# 9

# %% [markdown]
# # Exercice 3
# Écrivez un programme affichant le mot le plus long d’une phrase entrée par l’utilisateur.

# %%
# Correction
phrase = input ( " Entrez une phrase : " )
mots = phrase.split( " " )
motPlusLong = " "
tailleMotPlusLong = 0
for mot in mots :
    tailleMot = len (mot)
    if tailleMot >= tailleMotPlusLong :
        motPlusLong = mot
        tailleMotPlusLong = tailleMot
print (" Le mot le plus long est " + motPlusLong.upper() + " avec " + str ( tailleMotPlusLong ) + " lettres. " )
# Out:
#  Entrez une phrase : Hello every one in my classeroom
#  Le mot le plus long est CLASSEROOM avec10 lettres.

# %% [markdown]
# # Exercice 4
# Écrire une fonction miroir_string qui prend en paramètre une chaîne de caractères et qui inverse ses caractères dans une liste (la chaîne de caractères passée en paramètre est modifiée). Pour tester votre fonction, écrivez un programme affichant l’argument du programme à l’envers. Par
# exemple :
# ch="Trace"
# miroir (ch)
# > [e,c,a,r,t]

# %%
# Correction
#Programme qui copie une chaine dans une autre en introduisant des '*' entre
#les caractères
ch1 = "trace" #liste des caractères de la chaine a inversée
ch2 = []#liste de la chaine inversée initialisée avec n'importe quoi
#on lit ch1 a partir du dernier caractère et on les copient un par un
#dans ch2
for i in range(0,len(ch1)):
    ch2.append (ch1[len(ch1)-i-1])

print(ch2)
# Out:
# ['e', 'c', 'a', 'r', 't']

# %% [markdown]
# # Exercice 5
#
# Ecrire dans un fichier fizzbuzz.py un programme qui affiche les nombres de 1 à 100, sauf:
# • si le nombre est un multiple de 3 ou se termine par 3, auquel cas il affiche "Fizz"
# • si le nombre est un multiple de 7 ou se termine par 7, auquel cas il affiche "Buzz"
# • si le nombre vérifie les 2 propositions, le programme affiche "FizzBuzz"
# Le tester, et vérifier que l’on obtient bien (pour les 1`eres valeurs) "1 2 Fizz 4 5 Fizz Buzz 8 Fizz 10 11
# Fizz Fizz Buzz Fizz 16 Buzz Fizz ...."

# %%
# Correction
# boucle de 1 `a 100 */
for i in range(0,100):
    # multiple de 3 ou se termine par 3 */
     fizz = (i%3==0) or (i%10==3)
    # multiple de 7 ou se termine par 7 */
     buzz = (i%7==0) or (i%10==7)
     if (fizz):
        print( "Fizz")
     if (buzz):
        print( "Buzz")
# Si ni l’un ni l’autre */
     if (not(fizz or buzz)):
        print(i)
        #print( " ")
# Out:
# Fizz
# Buzz
# 1
# 2
# Fizz
# 4
# 5
# Fizz
# Buzz
# 8
# Fizz
# 10
# 11
# Fizz
# Fizz
# Buzz
# Fizz
# 16
# Buzz
# Fizz
# 19
# 20
# Fizz
# Buzz
# 22
# Fizz
# Fizz
# 25
# 26
# Fizz
# Buzz
# Buzz
# 29
# Fizz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# Buzz
# 38
# Fizz
# 40
# 41
# Fizz
# Buzz
# Fizz
# 44
# Fizz
# 46
# Buzz
# Fizz
# Buzz
# 50
# Fizz
# 52
# Fizz
# Fizz
# 55
# Buzz
# Fizz
# Buzz
# 58
# 59
# Fizz
# 61
# 62
# Fizz
# Buzz
# 64
# 65
# Fizz
# Buzz
# 68
# Fizz
# Buzz
# 71
# Fizz
# Fizz
# 74
# Fizz
# 76
# Buzz
# Fizz
# 79
# 80
# Fizz
# 82
# Fizz
# Fizz
# Buzz
# 85
# 86
# Fizz
# Buzz
# 88
# 89
# Fizz
# Buzz
# 92
# Fizz
# 94
# 95
# Fizz
# Buzz
# Buzz
# Fizz

# %% [markdown]
# # Exercice 6
# Créez un programme tirant un nombre au hasard entre 1 et 20 et demandant à l’utilisateur de deviner ce nombre en lui indiquant si sa proposition est supérieure ou inférieure au nombre tiré.
# Exemple :
# Entrez un nombre : 7
# C'est plus
# Entrez un nombre : 13
# C'est moins
# Entrez un nombre : 10
# Gagné !

# %%
#!/ usr / bin /env python3 
from random import randint 
nombre = randint (1 ,20) 
reponse = 0 
print( " Devinez le nombre que j’ai en tête ! " ) 
while reponse != nombre : 
    reponse = int( input ( " Entrez un nombre : " ) ) 
    if nombre < reponse : 
        print ( "C’est moins " ) 
    elif nombre > reponse : 
        print ( "C ’est plu s " ) 
print ( "Gagné ! " )
# Out:
#  Devinez le nombre que j’ai en tête !
#  Entrez un nombre : 15
# C’est moins
#  Entrez un nombre : 10
# C ’est plu s
#  Entrez un nombre : 12
# C ’est plu s
#  Entrez un nombre : 14
# Gagné !

# %% [markdown]
# # Exercice 7
# Soit un tableau 𝑇 trié par ordre croissant de ses valeurs. Écrire une fonction qui retourne le tableau inverse de 𝑇.

# %%
# Correction
def inverse(t):
    inv=[]
    i=len(t)-1
    while i >= 0:
        inv.append(t[i])
        i -= 1
    return inv

inverse([1, 3, 3, 6, 7, 9, 10, 10, 12])
# Out:
# [12, 10, 10, 9, 7, 6, 3, 3, 1]

# %% [markdown]
# # 2. Format CSV

# %%
import csv # bibliothèque csv en python 
f = open("fichier.csv", "r+")  # ouverture du fichier csv en mode lecture
r = csv.reader(f, delimiter=",") 
lignes = list(r) 
f.seek(0) # retour au début du fichier 
w = csv.writer(f, delimiter="#") 
w.writerows(lignes) 
f.close() # fermeture du fichier

# %% [markdown]
# # Exercice 8
# Écrire une fonction statsCSV(fichier) où fichier est le nom d'un fichier CSV et qui affiche le nombre de lignes et le nombre colonnes de la table stockée dans le fichier.

# %%
# Correction
import csv
def statsCSV(fichier):
    
    file = open(fichier,"r")
    donnees = csv.reader(file)
    ligne = list(donnees)
    nb_ligne= len(ligne)
    nb_colonne=len(ligne[0])
    file.close()
    return  nb_ligne, nb_colonne
    
print(statsCSV("BDtest.csv"))
# Out:
# (10, 5)

# %% [markdown]
# # Exercice 9
# 1- Ouvrir fichier "laposte.hexasmal.csv" déposé sur https://github.com/Houda-Harbaoui/Analyse-de-donn-es (à télécharger)  et placer dans le même répertoire que ce notebook) qui contient la liste des communes françaises avec leur code postal et code INSEE. Le nombre de communes de chaque département est compté et stocké dans un tableau. (On notera le traitement particulier de la Corse.)
#
# # Question 1:
#
# Trouver le numéro du département contenant le moins de communes.
#
# # Question 2:
#
# Aller chercher dans le fichier "departement.csv" déposé sur https://github.com/Houda-Harbaoui/Analyse-de-donn-es le nom de ce département.

# %%
#Question 1
f=open('laposte_hexasmal.csv','r')
t=99*[0]
line=f.readline()
line=f.readline()
while (line):
    l=line.split(';')
    #print(l)
    i=int(l[2][:2])
    #print(i)
    t[i]=t[i]+1
    #print(t[i])
    line=f.readline()

f.close()
m=t[1]
for n in t:
    if n>0 and n<m:
        m=n
        
d=t.index(m)
print(d)
# Out:
# 75

# %%
#Question 2
# The strip() method returns a copy of the string by removing both the leading 
#and the trailing characters (based on the string argument passed).
#if d>20:
 #   d+=1
    
g=open('departement.csv','r')
for j in range(d):
    line=g.readline()
    
liste=line.split(',')
code=(liste[1]).strip('"')
i=int(code)
print (liste[2].strip('"'))
    
g.close()
# Out:
# Paris

# %% [markdown]
# # Exercice 9
# Créer un fichier CSV "resultats.csv" listant tous les étudiants de la promo, triés par ordre croissant sur le nom.
# Chaque ligne a les colonnes suivantes :
#
#     NOM : nom de l'étudiant,
#
#     PRENOM : prénom de l'étudiant,
#
#     AGE : âge de l'étudiant,
#
#     NOTE : moyenne de l'année sur 20.
#
# Question1:
# Ecrire une fonction qui lit le fichier CSV et qui écrit :
#
#     le nombre d'étudiants ayant une note supérieure à 10,
#
#     le nombre d'étudiant ayant une note inférieure à 10,
#
#     la moyenne de la promo,
#
#     le major de promo,
#
#     l'étudiant ayant la plus basse note.
#
# Ecrire une fonction qui tri les résultats issu du fichier "resultats.csv" suivant la note par ordre croissant et qui sauvegarde le résultat dans un nouveau fichier CSV "resultats-tries.csv".

# %% [markdown]
# # Exercice Bonus
# Écrivez un programme permettant à un utilisateur de deviner un mot choisi au hasard dans un fichier dans lequel chaque ligne comporte un mot en capitale. L’utilisateur a 7 chances pour découvrir le mot en proposant une lettre à chaque fois. Si la lettre proposée n’est pas dans le mot, une chance lui est retirée.
# Exemple :
# - - - - - - - - (7 chances)
# Entrez une lettre : S
# - - - - - - - - (6 chances)
# Entrez une lettre : O
# - O - - - - - - (6 chances)
# ...
# Bravo ! Le mot était JOURNAUX.
