# %% [markdown]
# ## Exercice 1: Programmer le tri par sélection.

# %% [raw]
# Entree : T liste de n nombres.
# Sortie : liste T triée
# Traitement :
# Pour j de 1 à n
# indiceMin <-- j
#     Pour k de j + 1 à n
#          si T [k] < T [j] alors
#               indiceMin <-- k
#         finSi
#     finPour
# Echange de T [j] et T [indiceMin] si j!= indiceMin
# finPour

# %% [markdown]
# # Exercice 2: Le tableau est-il trié ?
# Écrire une fonction est_trie(t), qui prend en paramètre un tableau t et qui renvoie true si le tableau est trié et false sinon.

# %% [markdown]
# # Exercice 3:

# %% [markdown]
# - Calculer la moyenne des étudiants de la liste Etudiants en applicant la formule suivante:
#     - moyenne= (CC * 0.4)+ (examen * 0.6)

# %% [markdown]
# - Etudiants=["Fabien","Sarah","François","Alexandre","Ali","Stépahne","Odette","Sylvie", "Mathieu","Anais"]
# -  CC=[10,15,9,12,13.75,17,8.75,10,11,9.25]
# -  examen=[12,8,14.5,12,11,11,9.75,10.5,15.25,13.75]
# - Moyenne= [ ]
# - Classement=[ ]
# ### Question 1:
# - Classer les étudiants en fonction de leurs moyenne en physique (dans l'ordre croissant puis décroissant)
# ### Question 2:
# - Quelle est la moyenne la plus élevée en physique? A quel étudiant appartient-elle?
# ### Question 3:
# - Écrire une fonction minMaxMoy() qui reçoit la liste des moyennes et qui renvoie le minimum, le maximum et la moyenne de cette liste.

# %%
# chercher le classement en triant la liste Moyenne

# %% [markdown]
# # Exercice 4:
# #### Question 1:
# - Ecrire une fonction StatSncf qui calcule le nombre de lignes et colonnes  dans le fichier retards-SNCF.csv printf("\n")
# #### Question 2:
# - Afficher tous les voyages Paris Nord-Lille
# - Calculer le nombre de voyages ayant départ Lille effectué en mois de novembre 2011
# - Créer un fichier Atlantique ou copier les voyages ayant axe "atlantique" entre 2014 et 2017
# - Calculer le nombre minimal et maximal des trains programmés
# - Calculer la moyenne des trains programmés en 2013
# - Calculer le nombre total des TGVs annulés par SNCF entre 2011 et 2017
# #### Question 3:
#    1 - Creer un fichier "Planification.csv"
#
#    2 -Copier la colonne les colonnes F,G, H,I dans le fichier "Planification.csv".
#
#    3  - "dans le fichier "Planification.csv": rajouter une colonne nommée "Planification" qui prendra 3 attributs:
#     - "Parfaite" si le taux de régularité égal à 100%
#     - "Bonne" si le taux de régularité est situé entre 80 et 90%
#     - "Moyenne" si le taux de régularité est situé entre 60 et 80 %
#     - "Mauvaise" si le taux de régularité est inférieur à 60%

# %%
#Calculer la moyenne des trains programmés en 2013

# %%
#Calculer le nombre de voyages ayant départ Lille effectué en mois de novembre 2011

# %%
#Calculer le nombre minimal et maximal des trains programmés

# %%
#3  - "dans le fichier "Planification.csv": copier les colonnes F,G, H,I et K
#rajouter une colonne 
#- "Parfaite" si le taux de régularité égal à 100%
#   - "Bonne" si le taux de régularité est situé entre 80 et 90%
#  - "Moyenne" si le taux de régularité est situé entre 60 et 80 %
  #  - "Mauvaise" si le taux de régularité est inférieur à 60%

# %% [markdown]
# ##  Exercice 5:
# Créer un fichier csv composé de 4 colonnes:
# - CL1 nommée 'Année'
# - CL2 nommée  'Bissextile'
# - CL3 nommée 'Evenement sportif mondial'
#
# - La première colonne doit être remplie par les années entre 2002 et 2050
# - La deuxième colonne indique si l'année est bissextile ou non
# - LA troisième colonne doit indiquér l'évènement mondial en sport soit:
#     - coupe du monde en Foot sachant  qu'il est organisé une fois tous les 4 ans
#     - coupe du monde en Handball sachant  qu'il est réalisé une fois tous les 2 ans

# %% [markdown]
# ## Exercice 6
# Problème « Couicable »
# 1. Écrire une fonction nbDeChiffres(x) qui retourne le nombre de chiffres composant un
# entier x transmis en arguments.
# 2. Écrire une fonction extraitNombre(x,n,lg) qui extrait de x entier positif, à partir du
# énième chiffre en partant de la droite, le nombre composé de lg chiffres. Elle renvoie -1
# si les entrées ne sont pas correctes.
# Exemple 1, extraitNombre(45863047,4,3) renvoie 586.
# Exemple 2, extraitNombre(45863047,6,4) renvoie -1.
# 3. Écrire une fonction estPair(x) qui renvoie 1 si le nombre de chiffres de x est pair, 0
# sinon.
# 4. Écrire une fonction sommeDesChiffres(x) qui renvoie la somme des chiffres composant
# le nombre x transmis en arguments
# 5. Un nombre x est dit couicable si la somme des chiffres de sa partie droite est égale à
# la somme des chiffres de sa partie gauche. Le nombre de chiffres composant le nombre étudié doit être pair. Par exemple, 256823 est couicable.
#
# Écrire la fonction estCouicable(x) qui affiche si x, transmis en arguments, est un nombre couicable ou non
